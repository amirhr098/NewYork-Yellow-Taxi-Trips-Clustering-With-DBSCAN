# %% [markdown]
# <a href="https://colab.research.google.com/github/amirhr098/NewYork-Yellow-Taxi-Trips-Clustering-With-DBSCAN/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics import calinski_harabasz_score

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Files/train.csv')
data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.765602                  N            455
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
data['distance'] = np.sqrt((data['dropoff_longitude']-data['pickup_longitude'])**2 + (data['dropoff_latitude']-data['pickup_latitude'])**2) * 1000
X = pd.DataFrame(data,columns = ['trip_duration', 'distance'])
X.head()
# Out:
#    trip_duration   distance
# 0            455  17.679539
# 1            663  20.455904
# 2           2124  59.933799
# 3            429  13.438206
# 4            435  10.689569

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 2 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   trip_duration  1458644 non-null  int64
#  1   distance       1458644 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 22.3 MB

# %%
r = np.arange(1.65,2,0.05)
ms = np.arange(50,500,50)

# %%
for eps in r:
  for min in ms:
    dbscan = DBSCAN(eps = eps, min_samples=min)
    dbscan.fit(X)
    if(len(np.unique(dbscan.labels_))>1):
      calinski_harabasz_score(X, dbscan.labels_)
      print(str(calinski_harabasz_score(X, dbscan.labels_)),' =>  eps = ',eps,'  min_sampels = ', min)
    else:
      print('ERROR => eps = ',eps,' min_sampels = ', min)

# %% [markdown]
# 3.631744409309837  =>  eps =  0.05   min_sampels =  50
#
# 4.977548910011845  =>  eps =  0.05   min_sampels =  100
#
# 6.583762584252497  =>  eps =  0.05   min_sampels =  150
#
# 7.547292142677266  =>  eps =  0.05   min_sampels =  200
#
# ERROR => eps =  0.05  min_sampels =  250
#
# ERROR => eps =  0.05  min_sampels =  300
#
# ERROR => eps =  0.05  min_sampels =  350
#
# ERROR => eps =  0.05  min_sampels =  400
#
# ERROR => eps =  0.05  min_sampels =  450
#
# 3.378291217251763  =>  eps =  0.1   min_sampels =  50
#
# 5.208370932590151  =>  eps =  0.1   min_sampels =  100
#
# 6.637010901477077  =>  eps =  0.1   min_sampels =  150
#
# 8.292384633587734  =>  eps =  0.1   min_sampels =  200
#
# 8.677255258716599  =>  eps =  0.1   min_sampels =  250
#
# ERROR => eps =  0.1  min_sampels =  300
#
# ERROR => eps =  0.1  min_sampels =  350
#
# ERROR => eps =  0.1  min_sampels =  400
#
# ERROR => eps =  0.1  min_sampels =  450
#
# 1.4535205937745501  =>  eps =  0.15000000000000002   min_sampels =  50
#
# 5.386035126807206  =>  eps =  0.15000000000000002   min_sampels =  100
#
# 6.763849738959565  =>  eps =  0.15000000000000002   min_sampels =  150
#
# 8.748278648123264  =>  eps =  0.15000000000000002   min_sampels =  200
#
# 9.144546074937855  =>  eps =  0.15000000000000002   min_sampels =  250
#
# ERROR => eps =  0.15000000000000002  min_sampels =  300
#
# ERROR => eps =  0.15000000000000002  min_sampels =  350
#
# ERROR => eps =  0.15000000000000002  min_sampels =  400
#
# ERROR => eps =  0.15000000000000002  min_sampels =  450
#
# 2.5236023529773255  =>  eps =  0.2   min_sampels =  50
#
# 5.588895190865909  =>  eps =  0.2   min_sampels =  100
#
# 6.98442247696665  =>  eps =  0.2   min_sampels =  150
#
# 9.026464746190445  =>  eps =  0.2   min_sampels =  200
#
# 9.495119677265626  =>  eps =  0.2   min_sampels =  250
#
# ERROR => eps =  0.2  min_sampels =  300
#
# ERROR => eps =  0.2  min_sampels =  350
#
# ERROR => eps =  0.2  min_sampels =  400
#
# ERROR => eps =  0.2  min_sampels =  450
#
# 4.083841804668458  =>  eps =  0.25   min_sampels =  50
#
# 4.603793164612203  =>  eps =  0.25   min_sampels =  100
#
# 7.188315343249111  =>  eps =  0.25   min_sampels =  150
#
# 9.293235242006794  =>  eps =  0.25   min_sampels =  200
#
# 9.293235242006794  =>  eps =  0.25   min_sampels =  250
#
# ERROR => eps =  0.25  min_sampels =  300
#
# ERROR => eps =  0.25  min_sampels =  350
#
# ERROR => eps =  0.25  min_sampels =  400
#
# ERROR => eps =  0.25  min_sampels =  450
#
# 5.48712983563596  =>  eps =  0.3   min_sampels =  50
#
# 2.87796386705575  =>  eps =  0.3   min_sampels =  100
#
# 7.024458002493031  =>  eps =  0.3   min_sampels =  150
#
# 9.4043565246682  =>  eps =  0.3   min_sampels =  200
#
# 9.4043565246682  =>  eps =  0.3   min_sampels =  250
#
# ERROR => eps =  0.3  min_sampels =  300
#
# ERROR => eps =  0.3  min_sampels =  350
#
# ERROR => eps =  0.3  min_sampels =  400
#
# ERROR => eps =  0.3  min_sampels =  450
#
# 6.283642254342926  =>  eps =  0.35000000000000003   min_sampels =  50
#
# 3.805942501762494  =>  eps =  0.35000000000000003   min_sampels =  100
#
# 6.889221724033194  =>  eps =  0.35000000000000003   min_sampels =  150
#
# 8.812481557193255  =>  eps =  0.35000000000000003   min_sampels =  200
#
# 9.504403388662674  =>  eps =  0.35000000000000003   min_sampels =  250
#
# ERROR => eps =  0.35000000000000003  min_sampels =  300
#
# ERROR => eps =  0.35000000000000003  min_sampels =  350
#
# ERROR => eps =  0.35000000000000003  min_sampels =  400
#
# ERROR => eps =  0.35000000000000003  min_sampels =  450
#
# 7.435435392871959  =>  eps =  0.4   min_sampels =  50
#
# 5.50193736400913  =>  eps =  0.4   min_sampels =  100
#
# 5.614216698362577  =>  eps =  0.4   min_sampels =  150
#
# 8.945648646604132  =>  eps =  0.4   min_sampels =  200
#
# 9.63788528898655  =>  eps =  0.4   min_sampels =  250
#
# 10.08758679674892  =>  eps =  0.4   min_sampels =  300
#
# ERROR => eps =  0.4  min_sampels =  350
#
# ERROR => eps =  0.4  min_sampels =  400
#
# ERROR => eps =  0.4  min_sampels =  450
#
# 8.04636101063049  =>  eps =  0.45   min_sampels =  50
#
# 7.216471237096027  =>  eps =  0.45   min_sampels =  100
#
# 4.369062547755235  =>  eps =  0.45   min_sampels =  150
#
# 8.987210507355188  =>  eps =  0.45   min_sampels =  200
#
# 9.671273345797605  =>  eps =  0.45   min_sampels =  250
#
# 10.15440242013179  =>  eps =  0.45   min_sampels =  300
#
# ERROR => eps =  0.45  min_sampels =  350
#
# ERROR => eps =  0.45  min_sampels =  400
#
# ERROR => eps =  0.45  min_sampels =  450
#
# 8.850581730509246  =>  eps =  0.5   min_sampels =  50
#
# 8.878459166521928  =>  eps =  0.5   min_sampels =  100
#
# 4.609200401361628  =>  eps =  0.5   min_sampels =  150
#
# 9.045424837638302  =>  eps =  0.5   min_sampels =  200
#
# 9.726858011556569  =>  eps =  0.5   min_sampels =  250
#
# 10.129297777182986  =>  eps =  0.5   min_sampels =  300
#
# ERROR => eps =  0.5  min_sampels =  350
#
# ERROR => eps =  0.5  min_sampels =  400
#
# ERROR => eps =  0.5  min_sampels =  450
#
# 9.758927038529459  =>  eps =  0.55   min_sampels =  50
#
# 9.911764500433492  =>  eps =  0.55   min_sampels =  100
#
# 6.030323248574847  =>  eps =  0.55   min_sampels =  150
#
# 9.086778036652282  =>  eps =  0.55   min_sampels =  200
#
# 9.737956352306785  =>  eps =  0.55   min_sampels =  250
#
# 10.129297777182986  =>  eps =  0.55   min_sampels =  300
#
# ERROR => eps =  0.55  min_sampels =  350
#
# ERROR => eps =  0.55  min_sampels =  400
#
# ERROR => eps =  0.55  min_sampels =  450
#
# 10.304088570057992  =>  eps =  0.6000000000000001   min_sampels =  50
#
# 10.902406942784156  =>  eps =  0.6000000000000001   min_sampels =  100
#
# 8.082684522404545  =>  eps =  0.6000000000000001   min_sampels =  150
#
# 5.223136826253502  =>  eps =  0.6000000000000001   min_sampels =  200
#
# 9.826835689856244  =>  eps =  0.6000000000000001   min_sampels =  250
#
# 10.179360496297361  =>  eps =  0.6000000000000001   min_sampels =  300
#
# ERROR => eps =  0.6000000000000001  min_sampels =  350
#
# ERROR => eps =  0.6000000000000001  min_sampels =  400
#
# ERROR => eps =  0.6000000000000001  min_sampels =  450
#
# 10.89463571312181  =>  eps =  0.6500000000000001   min_sampels =  50
#
# 11.583277417557714  =>  eps =  0.6500000000000001   min_sampels =  100
#
# 9.552782292976953  =>  eps =  0.6500000000000001   min_sampels =  150
#
# 5.715831056169705  =>  eps =  0.6500000000000001   min_sampels =  200
#
# 9.826835689856244  =>  eps =  0.6500000000000001   min_sampels =  250
#
# 10.179360496297361  =>  eps =  0.6500000000000001   min_sampels =  300
#
# ERROR => eps =  0.6500000000000001  min_sampels =  350
#
# ERROR => eps =  0.6500000000000001  min_sampels =  400
#
# ERROR => eps =  0.6500000000000001  min_sampels =  450
#
# 11.581671917030818  =>  eps =  0.7000000000000001   min_sampels =  50
#
# 12.203200525167338  =>  eps =  0.7000000000000001   min_sampels =  100
#
# 10.752448015345328  =>  eps =  0.7000000000000001   min_sampels =  150
#
# 6.912291272861491  =>  eps =  0.7000000000000001   min_sampels =  200
#
# 9.860200054836179  =>  eps =  0.7000000000000001   min_sampels =  250
#
# 10.212746816266373  =>  eps =  0.7000000000000001   min_sampels =  300
#
# ERROR => eps =  0.7000000000000001  min_sampels =  350
#
# ERROR => eps =  0.7000000000000001  min_sampels =  400
#
# ERROR => eps =  0.7000000000000001  min_sampels =  450
#
# 11.906120240688034  =>  eps =  0.7500000000000001   min_sampels =  50
#
# 12.80406643563191  =>  eps =  0.7500000000000001   min_sampels =  100
#
# 11.732199400354775  =>  eps =  0.7500000000000001   min_sampels =  150
#
# 8.03698086384534  =>  eps =  0.7500000000000001   min_sampels =  200
#
# 6.872995991318511  =>  eps =  0.7500000000000001   min_sampels =  250
#
# 10.212746816266373  =>  eps =  0.7500000000000001   min_sampels =  300
#
# ERROR => eps =  0.7500000000000001  min_sampels =  350
#
# ERROR => eps =  0.7500000000000001  min_sampels =  400
#
# ERROR => eps =  0.7500000000000001  min_sampels =  450
#
# 12.538432871210217  =>  eps =  0.8   min_sampels =  50
#
# 13.659344711555601  =>  eps =  0.8   min_sampels =  100
#
# 12.699562291753386  =>  eps =  0.8   min_sampels =  150
#
# 9.790172720115157  =>  eps =  0.8   min_sampels =  200
#
# 6.544446573142775  =>  eps =  0.8   min_sampels =  250
#
# 10.262843007398969  =>  eps =  0.8   min_sampels =  300
#
# ERROR => eps =  0.8  min_sampels =  350
#
# ERROR => eps =  0.8  min_sampels =  400
#
# ERROR => eps =  0.8  min_sampels =  450
#
# 12.850058827703373  =>  eps =  0.8500000000000001   min_sampels =  50
#
# 13.914286601960471  =>  eps =  0.8500000000000001   min_sampels =  100
#
# 13.498108026662601  =>  eps =  0.8500000000000001   min_sampels =  150
#
# 10.97438824409697  =>  eps =  0.8500000000000001   min_sampels =  200
#
# 7.747451591903976  =>  eps =  0.8500000000000001   min_sampels =  250
#
# 10.279553294032903  =>  eps =  0.8500000000000001   min_sampels =  300
#
# ERROR => eps =  0.8500000000000001  min_sampels =  350
#
# ERROR => eps =  0.8500000000000001  min_sampels =  400
#
# ERROR => eps =  0.8500000000000001  min_sampels =  450
#
# 13.42738235994417  =>  eps =  0.9000000000000001   min_sampels =  50
#
# 14.55092211036333  =>  eps =  0.9000000000000001   min_sampels =  100
#
# 13.803770196940627  =>  eps =  0.9000000000000001   min_sampels =  150
#
# 12.044360634547756  =>  eps =  0.9000000000000001   min_sampels =  200
#
# 8.45740285493029  =>  eps =  0.9000000000000001   min_sampels =  250
#
# 7.55533082137996  =>  eps =  0.9000000000000001   min_sampels =  300
#
# ERROR => eps =  0.9000000000000001  min_sampels =  350
#
# ERROR => eps =  0.9000000000000001  min_sampels =  400
#
# ERROR => eps =  0.9000000000000001  min_sampels =  450
#
# 13.988167128442687  =>  eps =  0.9500000000000001   min_sampels =  50
#
# 14.648934202972622  =>  eps =  0.9500000000000001   min_sampels =  100
#
# 14.430331641948255  =>  eps =  0.9500000000000001   min_sampels =  150
#
# 12.805420771412187  =>  eps =  0.9500000000000001   min_sampels =  200
#
# 9.464376978949216  =>  eps =  0.9500000000000001   min_sampels =  250
#
# 7.541054484255466  =>  eps =  0.9500000000000001   min_sampels =  300
#
# ERROR => eps =  0.9500000000000001  min_sampels =  350
#
# ERROR => eps =  0.9500000000000001  min_sampels =  400
#
# ERROR => eps =  0.9500000000000001  min_sampels =  450
#
# 19.62789071575767  =>  eps =  1.0   min_sampels =  50
#
# 23.732286602589365  =>  eps =  1.0   min_sampels =  100
#
# 26.383199200696207  =>  eps =  1.0   min_sampels =  150
#
# 21.756949855985088  =>  eps =  1.0   min_sampels =  200
#
# 15.537821391578994  =>  eps =  1.0   min_sampels =  250
#
# 9.4799233527575  =>  eps =  1.0   min_sampels =  300
#
# 33.45206106917695  =>  eps =  1.0   min_sampels =  350
#
# 33.45206106917695  =>  eps =  1.0   min_sampels =  400
#
# 25.49830293310076  =>  eps =  1.0   min_sampels =  450
#
# 95.45201473688269  =>  eps =  1.05   min_sampels =  50
#
# 235.7213663775947  =>  eps =  1.05   min_sampels =  100
#
# 323.13687465319373  =>  eps =  1.05   min_sampels =  150
#
# 337.1804442429759  =>  eps =  1.05   min_sampels =  200
#
# 224.75069989061473  =>  eps =  1.05   min_sampels =  250
#
# 320.9790063163956  =>  eps =  1.05   min_sampels =  300
#
# 269.6349509942005  =>  eps =  1.05   min_sampels =  350
#
# 171.13701842757803  =>  eps =  1.05   min_sampels =  400
#
# 82.61230024055301  =>  eps =  1.05   min_sampels =  450
#
# 107.42258775587419  =>  eps =  1.1   min_sampels =  50
#
# 224.82405754725875  =>  eps =  1.1   min_sampels =  100
#
# 264.6765153041348  =>  eps =  1.1   min_sampels =  150
#
# 435.11483747758217  =>  eps =  1.1   min_sampels =  200
#
# 522.0866292729424  =>  eps =  1.1   min_sampels =  250
#
# 456.88292357672975  =>  eps =  1.1   min_sampels =  300
#
# 447.4032736129907  =>  eps =  1.1   min_sampels =  350
#
# 452.1576041456717  =>  eps =  1.1   min_sampels =  400
#
# 384.0891782238176  =>  eps =  1.1   min_sampels =  450
#
# 130.8695437032206  =>  eps =  1.1500000000000001   min_sampels =  50
#
# 340.6768529263612  =>  eps =  1.1500000000000001   min_sampels =  100
#
# 368.55796328709334  =>  eps =  1.1500000000000001   min_sampels =  150
#
# 562.720753374818  =>  eps =  1.1500000000000001   min_sampels =  200
#
# 435.57119822621036  =>  eps =  1.1500000000000001   min_sampels =  250
#
# 593.9954991699354  =>  eps =  1.1500000000000001   min_sampels =  300
#
# 576.3932200067424  =>  eps =  1.1500000000000001   min_sampels =  350
#
# 689.122305919633  =>  eps =  1.1500000000000001   min_sampels =  400
#
# 562.8759087560218  =>  eps =  1.1500000000000001   min_sampels =  450
#
# 165.4032814065192  =>  eps =  1.2000000000000002   min_sampels =  50
#
# 287.55775120787814  =>  eps =  1.2000000000000002   min_sampels =  100
#
# 674.3471679763198  =>  eps =  1.2000000000000002   min_sampels =  150
#
# 575.0098841957255  =>  eps =  1.2000000000000002   min_sampels =  200
#
# 633.9019649877557  =>  eps =  1.2000000000000002   min_sampels =  250
#
# 1085.9497909220675  =>  eps =  1.2000000000000002   min_sampels =  300
#
# 702.0553055812477  =>  eps =  1.2000000000000002   min_sampels =  350
#
# 718.3668813415821  =>  eps =  1.2000000000000002   min_sampels =  400
#
# 552.11747830728  =>  eps =  1.2000000000000002   min_sampels =  450
#
# 153.09534591771006  =>  eps =  1.2500000000000002   min_sampels =  50
#
# 413.49110381258555  =>  eps =  1.2500000000000002   min_sampels =  100
#
# 538.9789397317068  =>  eps =  1.2500000000000002   min_sampels =  150
#
# 517.4353069683503  =>  eps =  1.2500000000000002   min_sampels =  200
#
# 757.8034060433469  =>  eps =  1.2500000000000002   min_sampels =  250
#
# 620.4356114979612  =>  eps =  1.2500000000000002   min_sampels =  300
#
# 513.4975748637187  =>  eps =  1.2500000000000002   min_sampels =  350
#
# 799.13068551367  =>  eps =  1.2500000000000002   min_sampels =  400
#
# 686.2412100083113  =>  eps =  1.2500000000000002   min_sampels =  450
#
# 163.38881383931323  =>  eps =  1.3   min_sampels =  50
#
# 389.7355580947628  =>  eps =  1.3   min_sampels =  100
#
# 621.1784943395  =>  eps =  1.3   min_sampels =  150
#
# 810.4531503793814  =>  eps =  1.3   min_sampels =  200
#
# 1065.1240596090593  =>  eps =  1.3   min_sampels =  250
#
# 865.368499036784  =>  eps =  1.3   min_sampels =  300
#
# 1234.1169883305226  =>  eps =  1.3   min_sampels =  350
#
# 792.9475635687879  =>  eps =  1.3   min_sampels =  400
#
# 761.8131792869448  =>  eps =  1.3   min_sampels =  450
#
# 146.69728734089327  =>  eps =  1.35   min_sampels =  50
#
# 475.6832683845586  =>  eps =  1.35   min_sampels =  100
#
# 576.0979059130249  =>  eps =  1.35   min_sampels =  150
#
# 947.8568100234165  =>  eps =  1.35   min_sampels =  200
#
# 1026.3999680605552  =>  eps =  1.35   min_sampels =  250
#
# 848.1211426812832  =>  eps =  1.35   min_sampels =  300
#
# 657.3446430741851  =>  eps =  1.35   min_sampels =  350
#
# 719.741069265033  =>  eps =  1.35   min_sampels =  400
#
# 690.5609678288879  =>  eps =  1.35   min_sampels =  450
#
# 156.2293557139036  =>  eps =  1.4000000000000001   min_sampels =  50
#
# 484.12271291489736  =>  eps =  1.4000000000000001   min_sampels =  100
#
# 807.4187517218268  =>  eps =  1.4000000000000001   min_sampels =  150
#
# 871.1554908640098  =>  eps =  1.4000000000000001   min_sampels =  200
#
# 694.9629909866844  =>  eps =  1.4000000000000001   min_sampels =  250
#
# 955.6588688740836  =>  eps =  1.4000000000000001   min_sampels =  300
#
# 616.3853144110622  =>  eps =  1.4000000000000001   min_sampels =  350
#
# 1235.2127636495184  =>  eps =  1.4000000000000001   min_sampels =  400
#
# 1262.5762578882056  =>  eps =  1.4000000000000001   min_sampels =  450
#
# 157.9632824512263  =>  eps =  1.4500000000000002   min_sampels =  50
#
# 518.1431367205076  =>  eps =  1.4500000000000002   min_sampels =  100
#
# 908.5216179075284  =>  eps =  1.4500000000000002   min_sampels =  150
#
# 766.6869823628394  =>  eps =  1.4500000000000002   min_sampels =  200
#
# 799.8773926565066  =>  eps =  1.4500000000000002   min_sampels =  250
#
# 1612.5892430238976  =>  eps =  1.4500000000000002   min_sampels =  300
#
# 1161.7336002714574  =>  eps =  1.4500000000000002   min_sampels =  350
#
# 1038.3117794312402  =>  eps =  1.4500000000000002   min_sampels =  400
#
# 940.6931669943832  =>  eps =  1.4500000000000002   min_sampels =  450
#
# 158.7244150281496  =>  eps =  1.5000000000000002   min_sampels =  50
#
# 541.454084842553  =>  eps =  1.5000000000000002   min_sampels =  100
#
# 741.6944578682424  =>  eps =  1.5000000000000002   min_sampels =  150
#
# 972.0794755251367  =>  eps =  1.5000000000000002   min_sampels =  200
#
# 1143.1075794311112  =>  eps =  1.5000000000000002   min_sampels =  250
#
# 1217.342277917919  =>  eps =  1.5000000000000002   min_sampels =  300
#
# 1209.6525745162928  =>  eps =  1.5000000000000002   min_sampels =  350
#
# 906.9184683839487  =>  eps =  1.5000000000000002   min_sampels =  400
#
# 1233.2732016723212  =>  eps =  1.5000000000000002   min_sampels =  450
#
# 164.3116539467615  =>  eps =  1.5500000000000003   min_sampels =  50
#
# 455.4820303209824  =>  eps =  1.5500000000000003   min_sampels =  100
#
# 819.8259235953508  =>  eps =  1.5500000000000003   min_sampels =  150
#
# 1126.5612886432489  =>  eps =  1.5500000000000003   min_sampels =  200
#
# 1090.9429715696863  =>  eps =  1.5500000000000003   min_sampels =  250
#
# 1060.1192114405278  =>  eps =  1.5500000000000003   min_sampels =  300
#
# 966.1330531177628  =>  eps =  1.5500000000000003   min_sampels =  350
#
# 757.8786935946157  =>  eps =  1.5500000000000003   min_sampels =  400
#
# 1285.8939936837746  =>  eps =  1.5500000000000003   min_sampels =  450
#
# 190.80469531894465  =>  eps =  1.6000000000000003   min_sampels =  50
#
# 803.6678603963325  =>  eps =  1.6000000000000003   min_sampels =  100
#
# 835.8457499280313  =>  eps =  1.6000000000000003   min_sampels =  150
#
# 962.0784247826574  =>  eps =  1.6000000000000003   min_sampels =  200
#
# 826.6098530025746  =>  eps =  1.6000000000000003   min_sampels =  250
#
# 748.5543347861188  =>  eps =  1.6000000000000003   min_sampels =  300
#
# 1848.386202524168  =>  eps =  1.6000000000000003   min_sampels =  350
#
# 1310.9935115729993  =>  eps =  1.6000000000000003   min_sampels =  400
#
# 1782.018519854208  =>  eps =  1.6000000000000003   min_sampels =  450
#
# 185.0840353340974  =>  eps =  1.65   min_sampels =  50
#
# 811.2782406593274  =>  eps =  1.65   min_sampels =  100
#
# 929.6739394932159  =>  eps =  1.65   min_sampels =  150
#
# 769.2110126228318  =>  eps =  1.65   min_sampels =  200
#
# 1070.3703002056584  =>  eps =  1.65   min_sampels =  250
#
# 861.0484693616617  =>  eps =  1.65   min_sampels =  300
#
# 1667.8669016774961  =>  eps =  1.65   min_sampels =  350
#
# 1219.1089660877533  =>  eps =  1.65   min_sampels =  400
#
# 1237.99000134694  =>  eps =  1.65   min_sampels =  450
#
# 191.01774833334943  =>  eps =  1.7   min_sampels =  50
#
# 616.8641903582984  =>  eps =  1.7   min_sampels =  100
#
# 943.2639367851451  =>  eps =  1.7   min_sampels =  150
#
# 899.7033829642876  =>  eps =  1.7   min_sampels =  200
#
# 1812.979441937439  =>  eps =  1.7   min_sampels =  250
#
# 1361.8686849533196  =>  eps =  1.7   min_sampels =  300
#
# 1519.2952744532379  =>  eps =  1.7   min_sampels =  350
#
# 1575.1122522784174  =>  eps =  1.7   min_sampels =  400
#
# 1153.9479622905417  =>  eps =  1.7   min_sampels =  450
#
# 188.7163265680591  =>  eps =  1.75   min_sampels =  50
#
# 536.0433580316428  =>  eps =  1.75   min_sampels =  100
#
# 1436.1969464069432  =>  eps =  1.75   min_sampels =  150
#
# 1075.6037088583028  =>  eps =  1.75   min_sampels =  200
#
# 981.1368898742578  =>  eps =  1.75   min_sampels =  250
#
# 1534.7983299307798  =>  eps =  1.75   min_sampels =  300
#
# 1556.3660579610957  =>  eps =  1.75   min_sampels =  350
#
# 1175.2171803898598  =>  eps =  1.75   min_sampels =  400
#
# 1492.5648006418962  =>  eps =  1.75   min_sampels =  450
#
# 226.98372332441576  =>  eps =  1.8   min_sampels =  50
#
# 784.929124602097  =>  eps =  1.8   min_sampels =  100
#
# 1200.0292260166896  =>  eps =  1.8   min_sampels =  150
#
# 2065.408344898054  =>  eps =  1.8   min_sampels =  200
#
# 1546.812353834905  =>  eps =  1.8   min_sampels =  250
#
# 1306.230779699432  =>  eps =  1.8   min_sampels =  300
#
# 1028.5359132725266  =>  eps =  1.8   min_sampels =  350
#
# 1658.5293284440424  =>  eps =  1.8   min_sampels =  400
#
# 1753.6591506977068  =>  eps =  1.8   min_sampels =  450
#
# 247.81984972882861  =>  eps =  1.85   min_sampels =  50
#
# 741.4345991202132  =>  eps =  1.85   min_sampels =  100
#
# 1372.5226336593637  =>  eps =  1.85   min_sampels =  150
#
# 1887.7227726587691  =>  eps =  1.85   min_sampels =  200
#
# 1156.021871063839  =>  eps =  1.85   min_sampels =  250
#
# 1331.4022576669397  =>  eps =  1.85   min_sampels =  300
#
# 922.6856247576004  =>  eps =  1.85   min_sampels =  350
#
# 2713.9018826710508  =>  eps =  1.85   min_sampels =  400
#
# 1801.4404264350026  =>  eps =  1.85   min_sampels =  450
#
# 273.8004535576136  =>  eps =  1.9000000000000001   min_sampels =  50
#
# 775.2181605064811  =>  eps =  1.9000000000000001   min_sampels =  100
#
# 1226.2568868241635  =>  eps =  1.9000000000000001   min_sampels =  150
#
# 1594.0320935217203  =>  eps =  1.9000000000000001   min_sampels =  200
#
# 1259.9008288696357  =>  eps =  1.9000000000000001   min_sampels =  250
#
# 2036.9447348680008  =>  eps =  1.9000000000000001   min_sampels =  300
#
# 1161.0218795473108  =>  eps =  1.9000000000000001   min_sampels =  350
#
# 1391.0536475740103  =>  eps =  1.9000000000000001   min_sampels =  400
#
# 1440.8944414220239  =>  eps =  1.9000000000000001   min_sampels =  450
#
# 302.9465644486051  =>  eps =  1.9500000000000002   min_sampels =  50
#
# 733.6067828006076  =>  eps =  1.9500000000000002   min_sampels =  100
#
# 1316.7973596332101  =>  eps =  1.9500000000000002   min_sampels =  150
#
# 1490.4047730761822  =>  eps =  1.9500000000000002   min_sampels =  200
#
# 1281.6569935161933  =>  eps =  1.9500000000000002   min_sampels =  250
#
# 2745.4420020496927  =>  eps =  1.9500000000000002   min_sampels =  300
#
# 1099.1342883988164  =>  eps =  1.9500000000000002   min_sampels =  350
#
# 1767.7261897218932  =>  eps =  1.9500000000000002   min_sampels =  400
#
# 1472.1861660221346  =>  eps =  1.9500000000000002   min_sampels =  450
#
# 351.41199308337855  =>  eps =  2.0   min_sampels =  50
#
# 789.2107608306351  =>  eps =  2.0   min_sampels =  100
#
# 1015.8038006889183  =>  eps =  2.0   min_sampels =  150
#
# 1960.0774198643792  =>  eps =  2.0   min_sampels =  200
#
# 1817.0603300335217  =>  eps =  2.0   min_sampels =  250
#
# 2095.36038613846  =>  eps =  2.0   min_sampels =  300
#
# 1047.2644065274553  =>  eps =  2.0   min_sampels =  350
#
# 1210.077838495925  =>  eps =  2.0   min_sampels =  400
#
# 2261.9950525714016  =>  eps =  2.0   min_sampels =  450

# %% [markdown]
# # **Best Parameters**

# %%
dbscan = DBSCAN(eps=1.95, min_samples=300)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1.95, min_samples=300)

# %%
calinski_harabasz_score(X, dbscan.labels_)
# Out:
# 2745.4420020496927

# %%
np.unique(dbscan.labels_)
# Out:
# array([-1,  0,  1,  2,  3,  4,  5])

# %%
dbscan.get_params()
# Out:
# {'algorithm': 'auto',
#  'eps': 1.95,
#  'leaf_size': 30,
#  'metric': 'euclidean',
#  'metric_params': None,
#  'min_samples': 300,
#  'n_jobs': None,
#  'p': None}
